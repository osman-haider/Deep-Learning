# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Load and Preprocess the Text

# %%
# Sample text (you can replace this with a larger dataset)
text = """
Long Short-Term Memory (LSTM) networks, a variant of Recurrent Neural Networks (RNNs), are particularly effective for next word prediction tasks due to their ability to retain long-term dependencies in sequential data. These networks solve the vanishing gradient problem that limits traditional RNNs by introducing a memory cell and gated mechanisms to control the flow of information.
For next word prediction, an LSTM processes input sequences, such as a sentence fragment, to predict the most probable word that follows. The model starts by tokenizing and encoding the text into numerical sequences, ensuring that each word is represented as a unique token. During training, sliding windows of word sequences are created to generate input-output pairs, where the input is a sequence of preceding words and the output is the next word.
After passing through an embedding layer for dense word vector representations, the LSTM layer captures temporal dependencies in the input sequence. A final dense layer with a softmax activation predicts the probability of each word in the vocabulary as the next word. The model learns contextual relationships in text, enabling it to generate coherent and meaningful predictions. For example, given the input "The weather is very," the model might predict "sunny" as the next word.
This approach can be extended with techniques like bidirectional LSTMs, beam search, or temperature sampling to improve context understanding and diversity in predictions. Such models find applications in auto-completion, chatbots, and language modeling, making them essential in natural language processing tasks.
"""

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
word_index = tokenizer.word_index  # Dictionary of word -> index
vocab_size = len(word_index) + 1   # Vocabulary size (+1 for padding)

# Convert text to sequences of integers
sequences = []
for sentence in text.split("."):
    tokens = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokens)):
        # Create input-output pairs
        sequences.append(tokens[:i+1])

# Pad sequences to ensure uniform length
max_len = max([len(x) for x in sequences])


padded_input_sequences = pad_sequences(sequences, maxlen = max_len, padding='pre')

# Split into inputs (X) and outputs (y)
X = padded_input_sequences[:,:-1]
y = padded_input_sequences[:, -1]

# Convert outputs to one-hot encoding
y = to_categorical(y, num_classes=vocab_size)

# %%
# Reshape X to have the required dimensions (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
X.shape
# Out:
# (238, 32, 1)

# %%
y.shape
# Out:
# (238, 147)

# %%
vocab_size
# Out:
# 147

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (238, 32, 1)
# Shape of y: (238, 147)

# %%
# Remove the extra dimension from X
X = X.squeeze()  # Shape becomes (238, 32)

# %%
X.shape
# Out:
# (238, 32)

# %% [markdown]
# ## Build the LSTM Model

# %%
# Define the model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=100, input_length=X.shape[1]),  # Embedding layer
    LSTM(150, return_sequences=True),  # First LSTM, returns sequences
    LSTM(150),                         # Second LSTM, returns the final state
    Dense(vocab_size, activation='softmax')  # Output layer
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_13 (Embedding)             │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_21 (LSTM)                       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_22 (LSTM)                       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## train model

# %%
# Train the model
model.fit(X, y, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.0102 - loss: 4.9898
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.0572 - loss: 4.9288
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.0647 - loss: 4.7364
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.0626 - loss: 4.6721
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.0719 - loss: 4.5703
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.0500 - loss: 4.5899
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.0819 - loss: 4.4652
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.0595 - loss: 4.4457
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.0658 - loss: 4.3851
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.0666 - loss: 4.2976
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.0732 - loss: 4.1822
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.0947 - loss: 4.1543
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.0741 - loss: 4.0718
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.0893 - loss: 3.9768
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.0951 - loss: 3.8827
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.1016 - loss: 3.8047
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.1143 - loss: 3.7142
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.1190 - loss: 3.6958
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.1521 - loss: 3.5708
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.1193 - loss: 3.4958
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.1632 - loss: 3.3510
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.1421 - loss: 3.2925
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.1523 - loss: 3.2435
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.1871 - loss: 3.1109
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.2016 - loss: 3.0460
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.2168 - loss: 2.9975
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.2260 - loss: 2.8916
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.2615 - loss: 2.8700
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.2641 - loss: 2.7921
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.2343 - loss: 2.8167
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.2023 - loss: 2.7685
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.2071 - loss: 2.7145
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.2890 - loss: 2.6112
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.3329 - loss: 2.5112
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.2726 - loss: 2.4749
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3846 - loss: 2.3973
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3639 - loss: 2.2893
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.3749 - loss: 2.2973
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.3613 - loss: 2.2667
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.5030 - loss: 2.1317
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4422 - loss: 2.1023
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.5021 - loss: 2.0367
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.4489 - loss: 2.0315
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.5083 - loss: 1.9969
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5656 - loss: 1.9307
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.5825 - loss: 1.8998
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5913 - loss: 1.8622
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5801 - loss: 1.8205
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.5284 - loss: 1.8146
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6080 - loss: 1.7684
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6499 - loss: 1.6467
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6703 - loss: 1.6783
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.6550 - loss: 1.6240
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.6496 - loss: 1.5642
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.5943 - loss: 1.5832
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.5927 - loss: 1.6190
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7026 - loss: 1.5111
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.6464 - loss: 1.5519
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6794 - loss: 1.4877
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.7001 - loss: 1.4243
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7935 - loss: 1.3508
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.8106 - loss: 1.3536
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7603 - loss: 1.3325
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.7360 - loss: 1.3443
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.8403 - loss: 1.2383
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.8137 - loss: 1.2388
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.8351 - loss: 1.2169
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8567 - loss: 1.1855
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8130 - loss: 1.1991
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8400 - loss: 1.1687
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.8970 - loss: 1.1230
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8718 - loss: 1.1099
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8480 - loss: 1.0857
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8643 - loss: 1.0671
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.8822 - loss: 1.0538
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.8421 - loss: 1.0686
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8922 - loss: 0.9985
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8880 - loss: 0.9768
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8997 - loss: 0.9858
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.8612 - loss: 0.9517
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8800 - loss: 0.9698
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8702 - loss: 0.9813
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8695 - loss: 0.9354
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9288 - loss: 0.9057
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9395 - loss: 0.8568
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.8966 - loss: 0.8487
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.9223 - loss: 0.8417
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9200 - loss: 0.8010
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9528 - loss: 0.7947
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8540 - loss: 0.8652
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8087 - loss: 0.9148
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8459 - loss: 0.8705
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9202 - loss: 0.8232
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9483 - loss: 0.7670
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9560 - loss: 0.7345
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9725 - loss: 0.7223
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9727 - loss: 0.6753
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9783 - loss: 0.6610
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9536 - loss: 0.6774
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9713 - loss: 0.6831

# %% [markdown]
# ## Predict the Next Word

# %%
import time
text = "After passing through an embedding"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# After passing through an embedding layer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# After passing through an embedding layer for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# After passing through an embedding layer for dense
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# After passing through an embedding layer for dense dense
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# After passing through an embedding layer for dense dense word
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# After passing through an embedding layer for dense dense word vector
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# After passing through an embedding layer for dense dense word vector vector
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# After passing through an embedding layer for dense dense word vector vector representations
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# After passing through an embedding layer for dense dense word vector vector representations the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# After passing through an embedding layer for dense dense word vector vector representations the the
